# %%
import xarray as xr
import pandas as pd
import numpy as np
import seaborn as sns
import pymannkendall as pmk
import matplotlib.pyplot as plt
from scipy import stats

# %%
temp = 'timeseries-tas-monthly-mean_cru_monthly_cru-ts4.06-timeseries_mean_1901-2021.nc.'
temp = xr.open_dataset(temp)

# %%
temp
# Out:
# <xarray.Dataset>
# Dimensions:                      (time: 1452, lat: 360, lon: 720, bnds: 2)
# Coordinates:
#   * time                         (time) datetime64[ns] 1901-01-16 ... 2021-12-16
#   * lat                          (lat) float32 -89.75 -89.25 ... 89.25 89.75
#   * lon                          (lon) float32 -179.8 -179.2 ... 179.2 179.8
#   * bnds                         (bnds) int32 0 1
# Data variables:
#     timeseries-tas-monthly-mean  (time, lat, lon) float32 ...
#     lon_bnds                     (lon, bnds) float64 ...
#     lat_bnds                     (lat, bnds) float64 ...
# Attributes:
#     references:   Information on the data is available at http://badc.nerc.ac...
#     history:      Fri 20 May 20:00:15 BST 2022 : User f098 : Program makegrid...
#     source:       Run ID = 2205201912. Data generated from:tmp.2204291209.dtb
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     title:        CRU TS4.06 Mean Temperature
# ...

# %%
temp['time']
# Out:
# <xarray.DataArray 'time' (time: 1452)>
# array(['1901-01-16T00:00:00.000000000', '1901-02-15T00:00:00.000000000',
#        '1901-03-16T00:00:00.000000000', ..., '2021-10-16T00:00:00.000000000',
#        '2021-11-16T00:00:00.000000000', '2021-12-16T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1901-01-16 1901-02-15 ... 2021-12-16
# Attributes:
#     long_name:  time

# %%
temp['timeseries-tas-monthly-mean'].plot()
# Out:
# (array([2.7215000e+04, 7.2641500e+05, 3.7073590e+06, 5.8495430e+06,
#         7.9210320e+06, 1.0387519e+07, 1.5878383e+07, 1.9925544e+07,
#         2.9702521e+07, 3.7683090e+06]),
#  array([-58.5       , -48.68      , -38.86      , -29.039999  ,
#         -19.22      ,  -9.4       ,   0.42000046,  10.240001  ,
#          20.060001  ,  29.880001  ,  39.7       ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
temp['timeseries-tas-monthly-mean'].groupby('time.year').mean(...).plot()

# %%
temp['timeseries-tas-monthly-mean'].groupby('time.month').mean(...).plot()

# %%
temp['timeseries-tas-monthly-mean'].groupby('time.dayofyear').mean(...).plot()

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 7))
sns.histplot(temp['timeseries-tas-monthly-mean'].sel(lat=27.25, lon=-81.75), kde=True, bins=100, ax=ax[0][0])
sns.histplot(temp['timeseries-tas-monthly-mean'].sel(lat=27.25, lon=-81.75).groupby('time.year').mean(...), kde=True, bins=100, ax=ax[0][1])
sns.histplot(temp['timeseries-tas-monthly-mean'].sel(lat=27.25, lon=-81.75).groupby('time.year').max(...), kde=True, bins=100, ax=ax[1][0])
sns.histplot(temp['timeseries-tas-monthly-mean'].sel(lat=27.25, lon=-81.75).groupby('time.year').min(...), kde=True, bins=100, ax=ax[1][1])
plt.show()

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.year').max(...).plot()

# %%
temp['timeseries-tas-monthly-mean'].sel(time=slice('1990-01-01', '2022-01-01'), lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.year').mean(...).plot()

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.year').mean(dim='lat').plot()

# %%
print(temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.month').mean(dim='lat').max())
print(temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.month').mean(dim='lat').min())
# Out:
# <xarray.DataArray 'timeseries-tas-monthly-mean' ()>
# array(28.95682, dtype=float32)
# <xarray.DataArray 'timeseries-tas-monthly-mean' ()>
# array(-15.173333, dtype=float32)

# %%
g = temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.month').mean('time').plot.imshow('lon', 'lat', levels=np.arange(-16, 30, 1), col='month', col_wrap=3, robust=True,  cbar_kwargs={
    'orientation': 'horizontal',
    'shrink': 0.9,
    'aspect': 40,
    'pad':0.1
},)

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).resample(time='Y').mean(...).plot(figsize=(20, 7))

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).resample(time='5Y').mean(...).plot(figsize=(20, 7))

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).resample(time='10Y').mean(...).plot(figsize=(20, 7))

# %% [markdown]
# 12 month moving average, 10 year moving average with raw data

# %%
gb_year = temp['timeseries-tas-monthly-mean'].groupby('time.year').mean(...)

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
ax.plot(gb_year)
ax.plot(gb_year.rolling(year=5).mean(...))
ax.plot(gb_year.rolling(year=10).mean(...))
plt.show()

# %%
temp['timeseries-tas-monthly-mean'].sel(time=slice('1990-01-01', '2000-01-01'), lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.year').mean(...)
# Out:
# <xarray.DataArray 'timeseries-tas-monthly-mean' (year: 10)>
# array([12.285596 , 12.087788 , 11.699487 , 11.125649 , 12.045944 ,
#        11.965916 , 11.531995 , 11.318531 , 12.550264 , 12.3019705],
#       dtype=float32)
# Coordinates:
#   * year     (year) int64 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999

# %%
12.3019705 - 12.285596
# Out:
# 0.016374499999999514

# %%
0.016374499999999514 / 9
# Out:
# 0.0018193888888888348

# %%
temp['timeseries-tas-monthly-mean'].sel(time=slice('1990-01-01', '1990-12-31'), lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.dayofyear')
# Out:
# <xarray.DataArray 'timeseries-tas-monthly-mean' (dayofyear: 12)>
# array([ 2.9223886 ,  2.8365486 ,  7.2289605 , 11.823618  , 15.357227  ,
#        21.53492   , 23.007029  , 22.406893  , 19.663399  , 12.720973  ,
#         7.7523384 ,  0.17285652], dtype=float32)
# Coordinates:
#   * dayofyear  (dayofyear) int64 16 46 75 106 136 167 197 228 259 289 320 350

# %%
temp['timeseries-tas-monthly-mean'].sel(time=slice('1990-01-01', '1991-12-31'), lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.year').mean(...).differentiate('year')
# Out:
# <xarray.DataArray 'timeseries-tas-monthly-mean' (year: 2)>
# array([-0.19780827, -0.19780827], dtype=float32)
# Coordinates:
#   * year     (year) int64 1990 1991

# %%
temp['timeseries-tas-monthly-mean'].sel(time=slice('1990-01-01', '2021-12-31'), lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.year').mean(...).differentiate('year')
# Out:
# <xarray.DataArray 'timeseries-tas-monthly-mean' (year: 32)>
# array([-0.19780827, -0.29305458, -0.4810691 ,  0.17322874,  0.4201331 ,
#        -0.2569747 , -0.32369232,  0.50913477,  0.49171972, -0.32373   ,
#        -0.03181362,  0.05317163, -0.1306305 , -0.03398371,  0.17464066,
#         0.3994689 , -0.01088858, -0.5250511 , -0.29822206,  0.21197271,
#         0.25220966,  0.61113787, -0.2217784 , -0.73953295,  0.50963545,
#         0.6580534 ,  0.08590412, -0.3616948 , -0.43286657,  0.25815582,
#         0.4479866 ,  0.02412415], dtype=float32)
# Coordinates:
#   * year     (year) int64 1990 1991 1992 1993 1994 ... 2017 2018 2019 2020 2021

# %%
temp['time']=='1990-01-01'
# Out:
# <xarray.DataArray 'time' (time: 1452)>
# array([False, False, False, ..., False, False, False])
# Coordinates:
#   * time     (time) datetime64[ns] 1901-01-16 1901-02-15 ... 2021-12-16

# %%
temp_1990 = temp['timeseries-tas-monthly-mean'].sel(time='1990-01-16', lat=slice(26, 48), lon=slice(-123, -71))
temp_1990 = temp_1990.mean(dim=('lat', 'lon'))
temp_2000 = temp['timeseries-tas-monthly-mean'].sel(time='2000-12-16', lat=slice(26, 48), lon=slice(-123, -71))
temp_2000 = temp_2000.mean(dim=('lat', 'lon'))

# %%
difference = temp_2000 - temp_1990
mean_rate_of_change = difference / 9
mean_rate_of_change
# Out:
# <xarray.DataArray 'timeseries-tas-monthly-mean' ()>
# array(-0.52362336)

# %%
temp_1990 = temp['timeseries-tas-monthly-mean'].sel(time='1990-01-16', lat=slice(26, 48), lon=slice(-123, -71))
temp_1990 = temp_1990.mean(dim=('lat', 'lon'))
temp_1995 = temp['timeseries-tas-monthly-mean'].sel(time='1995-12-16', lat=slice(26, 48), lon=slice(-123, -71))
temp_1995 = temp_1995.mean(dim=('lat', 'lon'))

# %%
difference = temp_1995 - temp_1990
mean_rate_of_change = difference / 4
mean_rate_of_change
# Out:
# <xarray.DataArray 'timeseries-tas-monthly-mean' ()>
# array(-0.38817796)

# %%
gb_year = temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.year').mean(...)

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
ax.plot(gb_year.max(...))
ax.plot(gb_year.rolling(year=5).max(...))
ax.plot(gb_year.rolling(year=10).max(...))

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.dayofyear').max(...).plot()

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time.year').min(...).plot()

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).groupby('time').mean(...).plot(figsize=(20, 7))

# %%
temp['timeseries-tas-monthly-mean'].sel(lat=slice(26, 48), lon=slice(-123, -71)).resample(time='1Y').mean(...).plot()
plt.show()
